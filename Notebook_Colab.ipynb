# %% [markdown]
# <a href="https://colab.research.google.com/github/Huertas97/Kmeans_example/blob/main/Notebook_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Huertas97/Kmeans_example.git
# Out:
# Cloning into 'Kmeans_example'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 17 (delta 0), reused 14 (delta 0), pack-reused 0
# Unpacking objects: 100% (17/17), done.

# %%
# %cd Kmeans_example/
# Out:
# /content/Kmeans_example

# %%
# %run KMeans_scikit.py
# Out:
# FINAL RESULT:
# 	Cluster 1
# 		Number Points in Cluster 106
# 		Centroid: [1.28540631 6.2828904 ]
# 	Cluster 2
# 		Number Points in Cluster 177
# 		Centroid: [2.47809427 2.880651  ]
# 	Cluster 3
# 		Number Points in Cluster 116
# 		Centroid: [5.18877576 4.12046946]
# 	Cluster 4
# 		Number Points in Cluster 198
# 		Centroid: [1.13248556 1.92972056]
# 	Cluster 5
# 		Number Points in Cluster 87
# 		Centroid: [0.58956433 7.62899455]
# 	Cluster 6
# 		Number Points in Cluster 182
# 		Centroid: [2.64569565 1.32577123]
# 	Cluster 7
# 		Number Points in Cluster 133
# 		Centroid: [4.67996476 5.62801759]

# %% [markdown]
# <a href="https://colab.research.google.com/github/Huertas97/Kmeans_example/blob/main/Notebook_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Huertas97/Kmeans_example.git
# Out:
# Cloning into 'Kmeans_example'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 20 (delta 1), reused 13 (delta 0), pack-reused 0
# Unpacking objects: 100% (20/20), done.

# %%
# %cd Kmeans_example/
# Out:
# /content/Kmeans_example

# %% [markdown]
# ## KMeans Scikit-Learn

# %%
# %run KMeans_scikit.py
# Out:
# FINAL RESULT:
# 	Cluster 1
# 		Number Points in Cluster 180
# 		Centroid: [2.57164936 1.26796172]
# 	Cluster 2
# 		Number Points in Cluster 137
# 		Centroid: [4.66454626 5.61283256]
# 	Cluster 3
# 		Number Points in Cluster 99
# 		Centroid: [1.10130665 6.17955636]
# 	Cluster 4
# 		Number Points in Cluster 113
# 		Centroid: [5.20516591 4.08191726]
# 	Cluster 5
# 		Number Points in Cluster 185
# 		Centroid: [2.51010336 2.8332371 ]
# 	Cluster 6
# 		Number Points in Cluster 93
# 		Centroid: [0.81991696 7.63852906]
# 	Cluster 7
# 		Number Points in Cluster 192
# 		Centroid: [1.10989202 1.99249366]

# %% [markdown]
# ## KMeans

# %%
# %run KMeans.py
# Out:
# ITERATION 1
# 	Centroid Cluster 1: [2.2615206607375766, 2.3217969571086927]
# 	Centroid Cluster 2: [5.723854941465116, 4.948961887383721]
# 	Centroid Cluster 3: [2.2399443376282524, 6.5433390143048324]
#
# ITERATION 2
# 	Centroid Cluster 1: [2.068835940564832, 2.03782390784547]
# 	Centroid Cluster 2: [5.042005609546668, 4.884400418528889]
# 	Centroid Cluster 3: [1.1943600029241708, 6.799626555710902]
#
#
# FINAL RESULT:
# 	Cluster 1
# 		Number Points in Cluster 563
# 		Centroid: [2.068835940564832, 2.03782390784547]
# 	Cluster 2
# 		Number Points in Cluster 225
# 		Centroid: [5.042005609546668, 4.884400418528889]
# 	Cluster 3
# 		Number Points in Cluster 211
# 		Centroid: [1.1943600029241708, 6.799626555710902]
